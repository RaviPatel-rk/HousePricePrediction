# %% [markdown]
# # Cleaning test data and save as cleaned_test.csv as we did in train data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('test.csv')

# %%
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK     SQUARE_FT  \
# 0         Owner                   0     0        1       BHK    545.171340
# 1        Dealer                   1     1        2       BHK    800.000000
# 2        Dealer                   0     0        2       BHK   1257.096513
# 3        Dealer                   0     0        3       BHK   1400.329489
# 4         Owner                   0     0        1       BHK    430.477830
# ...         ...                 ...   ...      ...       ...           ...
# 68715    Dealer                   0     1        2       BHK    856.555505
# 68716    Dealer                   0     1        3       BHK   2304.147465
# 68717    Dealer                   1     1        1       BHK  33362.792750
# 68718    Dealer                   0     0        2       BHK   1173.708920
# 68719    Dealer                   0     0        3       BHK   2439.532944
#
# ...

# %%
df.shape
# Out:
# (68720, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68720 entries, 0 to 68719
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   POSTED_BY           68720 non-null  object
#  1   UNDER_CONSTRUCTION  68720 non-null  int64
#  2   RERA                68720 non-null  int64
#  3   BHK_NO.             68720 non-null  int64
#  4   BHK_OR_RK           68720 non-null  object
#  5   SQUARE_FT           68720 non-null  float64
#  6   READY_TO_MOVE       68720 non-null  int64
#  7   RESALE              68720 non-null  int64
#  8   ADDRESS             68720 non-null  object
#  9   LONGITUDE           68720 non-null  float64
#  10  LATITUDE            68720 non-null  float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 5.8+ MB

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        68720.000000  68720.000000  68720.000000  6.872000e+04
# mean             0.176557      0.316531      2.388198  2.762419e+03
# std              0.381296      0.465126      0.864577  1.640991e+05
# min              0.000000      0.000000      1.000000  1.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000310e+02
# 50%              0.000000      0.000000      2.000000  1.174982e+03
# 75%              0.000000      1.000000      3.000000  1.550265e+03
# max              1.000000      1.000000     31.000000  4.016393e+07
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE
# count   68720.000000  68720.000000  68720.000000  68720.000000
# mean        0.823443      0.933498     21.288045     76.919388
# std         0.381296      0.249159      6.179034     10.100950
# min         0.000000      0.000000    -38.391261   -118.354100
# ...

# %%
#checking the unique value_count in each column
for col in df.columns:
    print(df[col].value_counts())
    print("*"*20)
    print("*"*20)
# Out:
# Dealer     42437
# Owner      24920
# Builder     1363
# Name: POSTED_BY, dtype: int64
# ********************
# ********************
# 0    56587
# 1    12133
# Name: UNDER_CONSTRUCTION, dtype: int64
# ********************
# ********************
# 0    46968
# 1    21752
# Name: RERA, dtype: int64
# ********************
# ********************
# 2     30998
# 3     24756
# 1      8383
# 4      4001
# 5       394
# 6       106
# 7        17
# 8        15
# 9        13
# 12       13
# 10        8
# 20        6
# 11        4
# 13        3
# 16        1
# 18        1
# 31        1
# Name: BHK_NO., dtype: int64
# ********************
# ********************
# BHK    68662
# RK        58
# Name: BHK_OR_RK, dtype: int64
# ********************
# ********************
# 1000.000000    1111
# 1250.000000     688
# 800.000000      441
# 1200.000000     433
# 1600.000000     282
#                ...
# 611.060189        1
# 2100.005676       1
# 1150.173611       1
# 540.865385        1
# ...

# %%
#removing spaces from the ADDRESS and change the address as Other for vlaue_count<=10
df['ADDRESS'] = df['ADDRESS'].apply(lambda x:x.strip())
add_count = df['ADDRESS'].value_counts()

# %%
#vlue of Address having value_count <=10
add_counts10 = add_count[add_count <=10]
add_counts10
# Out:
# Kodigehalli,Bangalore                                                     10
# Tilak Nagar,Kanpur                                                        10
# Pipla,Nagpur                                                              10
# Manivakkam,Chennai                                                        10
# Sector 12 Kharghar,Maharashtra                                            10
#                                                                           ..
# Bandhavgarh Colony,Satna                                                   1
# Opp Madhav Dispensary, Near Dal Bazar Tiraha, Lashkar, Gwalior,Gwalior     1
# Talwandi,Kota                                                              1
# Gopalpur,Kolkata                                                           1
# Nagegowdanapalya,Bangalore                                                 1
# Name: ADDRESS, Length: 9846, dtype: int64

# %%
#changing the Address as other
df['ADDRESS'] = df['ADDRESS'].apply(lambda x: 'other' if x in add_counts10 else x)

# %%
df['ADDRESS'].value_counts()
# Out:
# other                            21540
# Zirakpur,Chandigarh               1051
# Raj Nagar Extension,Ghaziabad      516
# Whitefield,Bangalore               447
# Rajarhat,Kolkata                   346
#                                  ...
# Khadakpada,Maharashtra              11
# Hinjewadi,Lalitpur                  11
# Gorantla,Guntur                     11
# Vasant Vihar,Mumbai                 11
# Jogeshwari (West),Maharashtra       11
# Name: ADDRESS, Length: 1203, dtype: int64

# %%
#removing the value which value < 3000 square_ft/bhk_no.
#because it is outlier
df = df[((df['SQUARE_FT']/df['BHK_NO.'])>=300)]

# %%
df.shape
# Out:
# (66868, 11)

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        66868.000000  66868.000000  66868.000000  6.686800e+04
# mean             0.169184      0.310776      2.385625  2.822065e+03
# std              0.374917      0.462815      0.846075  1.663557e+05
# min              0.000000      0.000000      1.000000  3.000000e+02
# 25%              0.000000      0.000000      2.000000  9.239738e+02
# 50%              0.000000      0.000000      2.000000  1.195093e+03
# 75%              0.000000      1.000000      3.000000  1.565354e+03
# max              1.000000      1.000000     31.000000  4.016393e+07
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE
# count   66868.000000  66868.000000  66868.000000  66868.000000
# mean        0.830816      0.941093     21.260541     76.945354
# std         0.374917      0.235453      6.209770     10.187815
# min         0.000000      0.000000    -38.391261   -118.354100
# ...

# %%
df.drop(columns = ['BHK_OR_RK'],inplace = True)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.     SQUARE_FT  \
# 0         Owner                   0     0        1    545.171340
# 1        Dealer                   1     1        2    800.000000
# 2        Dealer                   0     0        2   1257.096513
# 3        Dealer                   0     0        3   1400.329489
# 4         Owner                   0     0        1    430.477830
# ...         ...                 ...   ...      ...           ...
# 68715    Dealer                   0     1        2    856.555505
# 68716    Dealer                   0     1        3   2304.147465
# 68717    Dealer                   1     1        1  33362.792750
# 68718    Dealer                   0     0        2   1173.708920
# 68719    Dealer                   0     0        3   2439.532944
#
#        READY_TO_MOVE  RESALE                             ADDRESS  LONGITUDE  \
# 0                  1       1                               other  21.262000
# ...

# %%
df.to_csv('cleaned_test.csv')
