# %% [markdown]
# # Cleaning train data and save it as cleaned_train.csv

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   ADDRESS                29451 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %%
df['ADDRESS'].value_counts()
# Out:
# Zirakpur,Chandigarh              509
# Whitefield,Bangalore             230
# Raj Nagar Extension,Ghaziabad    215
# Sector-137 Noida,Noida           139
# New Town,Kolkata                 131
#                                 ...
# Silpukhuri,Guwahati                1
# Maragondanahalli,Bangalore         1
# Swastik Park,Mumbai                1
# Pipla,Maharashtra                  1
# Sainath Nagar,Maharashtra          1
# Name: ADDRESS, Length: 6899, dtype: int64

# %%
for col in df.columns:
    print(df[col].value_counts())
    print("*"*20)
    print("*"*20)
# Out:
# Dealer     18291
# Owner      10538
# Builder      622
# Name: POSTED_BY, dtype: int64
# ********************
# ********************
# 0    24157
# 1     5294
# Name: UNDER_CONSTRUCTION, dtype: int64
# ********************
# ********************
# 0    20088
# 1     9363
# Name: RERA, dtype: int64
# ********************
# ********************
# 2     13324
# 3     10546
# 1      3574
# 4      1723
# 5       190
# 6        52
# 7        11
# 8        10
# 15        4
# 10        4
# 20        4
# 12        3
# 9         3
# 13        1
# 11        1
# 17        1
# Name: BHK_NO., dtype: int64
# ********************
# ********************
# BHK    29427
# RK        24
# Name: BHK_OR_RK, dtype: int64
# ********************
# ********************
# 1000.000000    479
# 1250.000000    294
# 800.000000     202
# 1200.000000    179
# 1600.000000    125
#               ...
# 1749.908859      1
# 1684.001981      1
# 1864.207221      1
# 1383.862040      1
# 1532.889018      1
# ...

# %%
df.isna().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
#df['ADDRESS'].unique()
# Out:
# array(['Ksfc Layout,Bangalore', 'Vishweshwara Nagar,Mysore',
#        'Jigani,Bangalore', ..., 'west mambalam,Chennai',
#        'Gandhi Nagar,Gulbarga', 'E3-108, Lake View Recidency,,Vapi'],
#       dtype=object)

# %%
df['SQUARE_FT'].min()
# Out:
# 3.0

# %%
df['ADDRESS'] = df['ADDRESS'].apply(lambda x:x.strip())
add_count = df['ADDRESS'].value_counts()

# %%
add_counts10 = add_count[add_count <=10]
add_counts10
# Out:
# Wanwadi,Pune                  10
# New Panvel,Maharashtra        10
# Pen,Raigad                    10
# Tripunithura,Kochi            10
# Sector-82 Gurgaon,Gurgaon     10
#                               ..
# Silpukhuri,Guwahati            1
# Maragondanahalli,Bangalore     1
# Swastik Park,Mumbai            1
# Pipla,Maharashtra              1
# Sainath Nagar,Maharashtra      1
# Name: ADDRESS, Length: 6326, dtype: int64

# %%
df['ADDRESS'] = df['ADDRESS'].apply(lambda x: 'other' if x in add_counts10 else x)

# %%
df['ADDRESS'].value_counts()
# Out:
# other                            13238
# Zirakpur,Chandigarh                509
# Whitefield,Bangalore               230
# Raj Nagar Extension,Ghaziabad      215
# Sector-137 Noida,Noida             139
#                                  ...
# Sector-79 Gurgaon,Gurgaon           11
# Calangute,Goa                       11
# Sector 12 Kharghar,Lalitpur         11
# Amruthahalli,Bangalore              11
# Jwalapur,Haridwar                   11
# Name: ADDRESS, Length: 574, dtype: int64

# %%
df = df[((df['SQUARE_FT']/df['BHK_NO.'])>=300)]

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        28665.000000  28665.000000  28665.000000  2.866500e+04
# mean             0.171882      0.311425      2.391488  2.032892e+04
# std              0.377285      0.463084      0.868735  1.927224e+06
# min              0.000000      0.000000      1.000000  3.000000e+02
# 25%              0.000000      0.000000      2.000000  9.234219e+02
# 50%              0.000000      0.000000      2.000000  1.195136e+03
# 75%              0.000000      1.000000      3.000000  1.567988e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   28665.000000  28665.000000  28665.000000  28665.000000
# mean        0.828118      0.937589     21.271184     76.861315
# std         0.377285      0.241904      6.237566     10.626273
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
df.shape
# Out:
# (28665, 12)

# %%
df = df[df['TARGET(PRICE_IN_LACS)'] <= 10000]

# %%
df.shape
# Out:
# (28662, 12)

# %%
df['SQUARE_FT'].unique()
# Out:
# array([1300.236407 , 1275.       ,  933.1597222, ..., 1022.641509 ,
#         927.0790093,  896.7741935])

# %%
df['price_per_sqft'] = df['TARGET(PRICE_IN_LACS)']*100000/df['SQUARE_FT']
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE  \
# ...

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count          28662.0000  28662.000000  28662.000000  2.866200e+04
# mean               0.1719      0.311458      2.391459  2.094681e+03
# std                0.3773      0.463097      0.868762  2.775864e+04
# min                0.0000      0.000000      1.000000  3.000000e+02
# 25%                0.0000      0.000000      2.000000  9.232963e+02
# 50%                0.0000      0.000000      2.000000  1.195111e+03
# 75%                0.0000      1.000000      3.000000  1.567366e+03
# max                1.0000      1.000000     20.000000  4.300000e+06
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count     28662.0000  28662.000000  28662.000000  28662.000000
# mean          0.8281      0.937583     21.272055     76.861235
# std           0.3773      0.241916      6.237310     10.626826
# min           0.0000      0.000000    -37.713008   -121.761248
# ...

# %%
df[df['price_per_sqft'] <= 101]
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK     SQUARE_FT  \
# 373       Owner                   0     0        4       BHK  4.333333e+05
# 2951      Owner                   0     0        2       BHK  1.093750e+05
# 3882      Owner                   0     0       10       BHK  4.250000e+04
# 8347      Owner                   0     1        3       BHK  1.333333e+03
# 14036     Owner                   0     0        3       BHK  1.923077e+03
# 15598     Owner                   0     0        3       BHK  7.928571e+05
# 17527    Dealer                   0     0        3       BHK  1.830986e+03
# 20398    Dealer                   0     0        3       BHK  2.173913e+05
# 20910    Dealer                   1     0        2       BHK  1.500000e+03
# 22155     Owner                   0     0        1       BHK  3.400000e+05
# 25241     Owner                   0     0        3       BHK  4.300000e+06
# ...

# %%
def remove_outlier(df):
    df_output = pd.DataFrame()
    for key,subdf in df.groupby('ADDRESS'):
        m=np.mean(subdf.price_per_sqft)
        
        st=np.std(subdf.price_per_sqft)
        
        gen_df = subdf[(subdf.price_per_sqft > (m-st)) & (subdf.price_per_sqft <= (m+st))]
        df_output = pd.concat([df_output,gen_df],ignore_index = True)
    return df_output

# %%
df = remove_outlier(df)

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        23251.000000  23251.000000  23251.000000  2.325100e+04
# mean             0.160036      0.291858      2.365533  2.068207e+03
# std              0.366647      0.454627      0.855805  3.046450e+04
# min              0.000000      0.000000      1.000000  3.000000e+02
# 25%              0.000000      0.000000      2.000000  9.250059e+02
# 50%              0.000000      0.000000      2.000000  1.181160e+03
# 75%              0.000000      1.000000      3.000000  1.549503e+03
# max              1.000000      1.000000     20.000000  4.300000e+06
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   23251.000000  23251.000000  23251.000000  23251.000000
# mean        0.839964      0.944648     21.227899     76.952296
# std         0.366647      0.228672      6.329282     10.813847
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
df.shape
# Out:
# (23251, 13)

# %%
def bhk_outlier(df):
    exclude_indices = np.array([])
    for ADDRESS ,ADDRESS_df in df.groupby('ADDRESS'):
        bhk_stats = {}
        for bhk,bhk_df in ADDRESS_df.groupby('BHK_NO.'):
            bhk_stats[bhk] = {
                'mean':np.mean(bhk_df.price_per_sqft),
                'std':np.std(bhk_df.price_per_sqft),
                'count':bhk_df.shape[0]
            }
            
        for bhk,bhk_df in ADDRESS_df.groupby('BHK_NO.'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exculde_indices = np.append(exclude_indices,bhk_df[bhk_df.price_per_sqft < (stats['mean'])].index.values)
    return df.drop(exclude_indices,axis = 'index')

# %%
df = bhk_outlier(df)

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        23251.000000  23251.000000  23251.000000  2.325100e+04
# mean             0.160036      0.291858      2.365533  2.068207e+03
# std              0.366647      0.454627      0.855805  3.046450e+04
# min              0.000000      0.000000      1.000000  3.000000e+02
# 25%              0.000000      0.000000      2.000000  9.250059e+02
# 50%              0.000000      0.000000      2.000000  1.181160e+03
# 75%              0.000000      1.000000      3.000000  1.549503e+03
# max              1.000000      1.000000     20.000000  4.300000e+06
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   23251.000000  23251.000000  23251.000000  23251.000000
# mean        0.839964      0.944648     21.227899     76.952296
# std         0.366647      0.228672      6.329282     10.813847
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
df.shape
# Out:
# (23251, 13)

# %%
df = df[df['price_per_sqft'] >= 100]

# %%
df.shape
# Out:
# (23238, 13)

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.      SQUARE_FT  \
# count        23238.000000  23238.000000  23238.000000   23238.000000
# mean             0.160083      0.292022      2.364963    1770.871895
# std              0.366691      0.454702      0.854369    7919.251141
# min              0.000000      0.000000      1.000000     300.000000
# 25%              0.000000      0.000000      2.000000     925.000000
# 50%              0.000000      0.000000      2.000000    1180.394308
# 75%              0.000000      1.000000      3.000000    1548.453174
# max              1.000000      1.000000     20.000000  246008.783300
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   23238.000000  23238.000000  23238.000000  23238.000000
# mean        0.839917      0.944617     21.228804     76.951787
# std         0.366691      0.228732      6.327806     10.816651
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %%
df.drop(columns = ['BHK_OR_RK','price_per_sqft'],inplace = True)

# %%
df.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.    SQUARE_FT  READY_TO_MOVE  \
# 0    Dealer                   0     0        3  1282.568807              1
# 1     Owner                   0     0        2  1200.087279              1
# 2    Dealer                   0     0        2  1099.796334              1
# 3     Owner                   0     0        3  1439.884809              1
# 4    Dealer                   0     0        2  1100.160440              1
#
#    RESALE                       ADDRESS  LONGITUDE  LATITUDE  \
# 0       1  6th Phase JP Nagar,Bangalore       35.0     136.0
# 1       1  6th Phase JP Nagar,Bangalore       35.0     136.0
# 2       1  6th Phase JP Nagar,Bangalore       35.0     136.0
# 3       1  6th Phase JP Nagar,Bangalore       35.0     136.0
# 4       1  6th Phase JP Nagar,Bangalore       35.0     136.0
#
#    TARGET(PRICE_IN_LACS)
# 0                   69.9
# 1                   55.0
# 2                   54.0
# 3                  120.0
# ...

# %%
df.to_csv("cleaned_train.csv")
